# %%
import tensorflow as tf
import matplotlib.pyplot as plt 
import numpy as np 
#from tensorflow.keras.preprocessing import ImageDataGenerator

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
print("ImageDataGenerator imported successfully!")
# Out:
# ImageDataGenerator imported successfully!

# %%
img = tf.keras.preprocessing.image.load_img(r'C:\Users\dkglt\Desktop\CNN\datasets\flower_photo\flower_photos\roses\873660804_37f5c6a46e_n.jpg')
img_arry = tf.keras.preprocessing.image.img_to_array(img)
img_arry = np.expand_dims(img_arry,0)

# %%
# creat imagdatagenrator with augmention params 
datagen = ImageDataGenerator(
    rotation_range=40,
    width_shift_range=0.2,
    height_shift_range=0.3,  
    shear_range=0.2, 
    zoom_range=0.2, 
    horizontal_flip=True, 
    fill_mode='nearest'
)

# %%
# genrate augmented img 
aug_img = datagen.flow(img_arry,batch_size=1)

# %%
#plot some augmented img 
fig, axes = plt.subplots(1,8,figsize=(15,15))
axes = axes.flatten()
for i in range(8):
    batch = next(aug_img)
    augmented_img = batch[0].astype('uint8')
    axes[i].imshow(augmented_img)
    axes[i].axis('off')

plt.show()

# %%
import matplotlib.pyplot as plt

# Plot some augmented images in 2 rows
fig, axes = plt.subplots(2, 4, figsize=(12, 6))  # 2 rows, 4 columns
axes = axes.flatten()  # Flatten to easily index axes as 1D array

for i in range(8):
    batch = next(aug_img)
    augmented_img = batch[0].astype('uint8')
    axes[i].imshow(augmented_img)
    axes[i].axis('off')

plt.tight_layout()
plt.show()
